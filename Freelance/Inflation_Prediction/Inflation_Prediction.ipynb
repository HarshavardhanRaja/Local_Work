# %%
import pandas as pd

# %%
data = pd.read_csv('converted.csv')
data.columns
# Out:
# Index(['Period', 'Inflation (Can)', 'Inflation (US)', 'GDP (B$)',
#        'Empl.Per. (M)', 'CPI (Can)', 'CPI (US)', 'CC (Can)', 'PC Util (Can)',
#        'PC Util (US)', 'Bus Conf (Can)', 'Bus Conf (US)', 'TSX', 'Retail YoY%',
#        'M3 T$', 'Gov Sp M$', 'EI (000s)', 'Disp.Inc. M$', 'Consum.Cr. M$',
#        'Exports M$', 'Tourist Arr. (Persons)'],
#       dtype='object')

# %%
data.tail()
# Out:
#           Period  Inflation (Can)  Inflation (US)     GDP (B$)  Empl.Per. (M)  \
# 2977  2021-02-25         2.042857        2.471429  1982.181571      18.791000
# 2978  2021-02-26         2.082143        2.503571  1983.111929      18.801825
# 2979  2021-02-27         2.121429        2.535714  1984.042286      18.812650
# 2980  2021-02-28         2.160714        2.567857  1984.972643      18.823475
# 2981  2021-03-01         2.200000        2.600000  1985.903000      18.834300
#
#       CPI (Can)    CPI (US)   CC (Can)  PC Util (Can)  PC Util (US)  ...  \
# 2977    139.500  264.559857  49.728571         81.600     74.414286  ...
# 2978    139.525  264.618143  49.871429         81.625     74.485714  ...
# 2979    139.550  264.676429  50.014286         81.650     74.557143  ...
# 2980    139.575  264.734714  50.157143         81.675     74.628571  ...
# 2981    139.600  264.793000  50.300000         81.700     74.700000  ...
#
# ...

# %%
data.describe()
# Out:
#        Inflation (Can)  Inflation (US)     GDP (B$)  Empl.Per. (M)  \
# count      2982.000000     2982.000000  2982.000000    2982.000000
# mean          1.493075        1.521026  1867.394472      18.112544
# std           0.622844        0.739949    78.818428       0.542486
# min          -0.400000       -0.200000  1647.178000      16.141600
# 25%           1.086667        1.100806  1814.341903      17.719866
# 50%           1.470000        1.652473  1850.217710      17.981296
# 75%           2.000000        2.063333  1940.639411      18.507158
# max           3.000000        2.900000  2001.982000      19.130300
#
#          CPI (Can)     CPI (US)     CC (Can)  PC Util (Can)  PC Util (US)  \
# count  2982.000000  2982.000000  2982.000000    2982.000000   2982.000000
# mean    130.226040   245.212205    52.226291      80.902985     76.507814
# std       4.969146     9.391263     3.718228       2.129472      2.628237
# ...

# %%
data.corr(method = 'spearman')
# Out:
#                         Inflation (Can)  Inflation (US)  GDP (B$)  \
# Inflation (Can)                1.000000        0.735081  0.515921
# Inflation (US)                 0.735081        1.000000  0.525230
# GDP (B$)                       0.515921        0.525230  1.000000
# Empl.Per. (M)                  0.525118        0.528127  0.979541
# CPI (Can)                      0.182027        0.302597  0.822513
# CPI (US)                       0.195246        0.326029  0.819938
# CC (Can)                       0.564851        0.545640  0.105966
# PC Util (Can)                  0.692100        0.556085  0.370419
# PC Util (US)                   0.557527        0.357492  0.046371
# Bus Conf (Can)                 0.527969        0.768448  0.461191
# Bus Conf (US)                  0.357971        0.285432 -0.089611
# TSX                            0.408635        0.507827  0.838203
# Retail YoY%                    0.097572        0.185084 -0.144073
# ...

# %%
import seaborn as sns
corr1 = data.corr(method = 'spearman')
corr2 = data.corr(method = 'pearson')
corr3 = data.corr(method = 'kendall')

# %%
sns.heatmap(corr1)
# Out:
# <AxesSubplot:>

# %%
print(corr2)
sns.heatmap(corr2)
# Out:
#                         Inflation (Can)  Inflation (US)  GDP (B$)  \
# Inflation (Can)                1.000000        0.684180  0.542413
# Inflation (US)                 0.684180        1.000000  0.527795
# GDP (B$)                       0.542413        0.527795  1.000000
# Empl.Per. (M)                  0.583095        0.554626  0.960421
# CPI (Can)                      0.131161        0.301842  0.795199
# CPI (US)                       0.106754        0.337636  0.778647
# CC (Can)                       0.656290        0.444294  0.161472
# PC Util (Can)                  0.741318        0.498692  0.394830
# PC Util (US)                   0.680372        0.359350  0.222619
# Bus Conf (Can)                 0.603836        0.716853  0.482734
# Bus Conf (US)                  0.465545        0.222841  0.019495
# TSX                            0.376638        0.410021  0.840641
# Retail YoY%                    0.336831        0.286899  0.194244
# ...

# %%
train_data = data.iloc[:2000,:]
test_data = data.iloc[2001:,:]

# %%
train_data.head()
#train_data.tail()
# Out:
#        Period  Inflation (Can)  Inflation (US)     GDP (B$)  Empl.Per. (M)  \
# 0  2013-01-01         0.500000        1.600000  1729.586000      17.508000
# 1  2013-01-02         0.522581        1.612903  1729.754355      17.509477
# 2  2013-01-03         0.545161        1.625806  1729.922710      17.510955
# 3  2013-01-04         0.567742        1.638710  1730.091065      17.512432
# 4  2013-01-05         0.590323        1.651613  1730.259419      17.513910
#
#     CPI (Can)    CPI (US)   CC (Can)  PC Util (Can)  PC Util (US)  ...  \
# 0  121.300000  231.679000  53.900000      80.400000     76.700000  ...
# 1  121.345161  231.719581  53.951613      80.409677     76.709677  ...
# 2  121.390323  231.760161  54.003226      80.419355     76.719355  ...
# 3  121.435484  231.800742  54.054839      80.429032     76.729032  ...
# 4  121.480645  231.841323  54.106452      80.438710     76.738710  ...
#
#    Bus Conf (US)           TSX  Retail YoY%     M3 T$      Gov Sp M$  \
# ...

# %%
test_data.head()
test_data.tail()
# Out:
#           Period  Inflation (Can)  Inflation (US)     GDP (B$)  Empl.Per. (M)  \
# 2977  2021-02-25         2.042857        2.471429  1982.181571      18.791000
# 2978  2021-02-26         2.082143        2.503571  1983.111929      18.801825
# 2979  2021-02-27         2.121429        2.535714  1984.042286      18.812650
# 2980  2021-02-28         2.160714        2.567857  1984.972643      18.823475
# 2981  2021-03-01         2.200000        2.600000  1985.903000      18.834300
#
#       CPI (Can)    CPI (US)   CC (Can)  PC Util (Can)  PC Util (US)  ...  \
# 2977    139.500  264.559857  49.728571         81.600     74.414286  ...
# 2978    139.525  264.618143  49.871429         81.625     74.485714  ...
# 2979    139.550  264.676429  50.014286         81.650     74.557143  ...
# 2980    139.575  264.734714  50.157143         81.675     74.628571  ...
# 2981    139.600  264.793000  50.300000         81.700     74.700000  ...
#
# ...
